# %% [markdown]
# <a href="https://colab.research.google.com/github/Luid1991/Luid1991/blob/main/Exercicio_23_04_Luid_Barbosa.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]

# %%
df = pd.DataFrame(zip(nome,idade,altura,peso),columns=['nome','idade','altura','peso'])
display(df)
# Out:
#       nome  idade  altura  peso
# 0  Douglas     45    1.85    70
# 1  Daniela      7    1.23    22
# 2    Pedro     65    1.75    87
# 3    Maria     64    1.67    64
# 4  Eduardo     42    1.82    96
# 5    Ester     37    1.73    68

# %%
'''
Agora vamos supor que nosso objetivo seja inserir uma nova coluna com
o sexo dos elementos
'''
sexo = ['M','F','M','F','M','F']
df['sexo'] = sexo
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
'''
Agora vamos supor que nosso desejo é inserir um novo elemento (linha ou registro)

'''
df.loc[6] = ['Tobias',18,1.67,65,'M']
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F
# 6   Tobias     18    1.67    65    M

# %%
'''
Agora vamos mudar o nome das colunas peso (massa) e sexo (genero)
'''
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     45    1.85     70      M
# 1  Daniela      7    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F
# 6   Tobias     18    1.67     65      M

# %%
'''
Agora vamos exibir as medidas descritivas dos atributos numéricos do
nosso dataframe
'''
medidas = df.describe()
display(medidas)
# Out:
#            idade    altura      massa
# count   7.000000  7.000000   7.000000
# mean   39.714286  1.674286  67.428571
# std    21.646511  0.207514  23.408383
# min     7.000000  1.230000  22.000000
# 25%    27.500000  1.670000  64.500000
# 50%    42.000000  1.730000  68.000000
# 75%    54.500000  1.785000  78.500000
# max    65.000000  1.850000  96.000000

# %%
'''
Agora você deverá converter idade do df em uma lista
chamada idades, altura do df em uma lista chamada alturas, e
massa do df em uma lista chamada massas, após isso,
você deverá calcular a mediana de cada lista, usando a biblioteca numpy
e depois inserir cada mediana em uma lista chamada mediana e por último
inserir a lista mediana no df medidas na última posição
'''

idades = list(df['idade'])
alturas = list(df['altura'])
massas = list(df['massa'])
import numpy as np
medi = np.median(idades)
meda = np.median(alturas)
medm = np.median(massas)
mediana = [medi, meda, medm]
medidas.loc['mediana'] = mediana
display(medidas)
# Out:
#              idade    altura      massa
# count     7.000000  7.000000   7.000000
# mean     39.714286  1.674286  67.428571
# std      21.646511  0.207514  23.408383
# min       7.000000  1.230000  22.000000
# 25%      27.500000  1.670000  64.500000
# 50%      42.000000  1.730000  68.000000
# 75%      54.500000  1.785000  78.500000
# max      65.000000  1.850000  96.000000
# mediana  42.000000  1.730000  68.000000

# %%
'''
Tarefa para 23/04/2024:

Criar as medidas:
1 - AIQ
2 - LI
3 - LS

e inserí-las nessa ordem no df medidas
'''
# Out:
# '\nTarefa para 23/04/2024:\n\nCriar as medidas:\n1 - AIQ\n2 - LI\n3 - LS\n\ne inserí-las nessa ordem no df medidas\n'

# %%
# Calcular os valores do primeiro quartil (Q1) e do terceiro quartil (Q3) para cada coluna

q1 = list(medidas.loc['25%'])  # Q1 é o valor do quartil 25%
q3 = list(medidas.loc['75%'])  # Q3 é o valor do quartil 75%

# Calcular o intervalo interquartil (AIQ) para cada coluna
aiq = [q3 - q1 for q1, q3 in zip(q1, q3)]

# Calcular os limites inferior (LI) para detecção de outliers para cada coluna
li = [q1 - 1.5 * aiq for q1, aiq in zip(q1, aiq)]

# Calcular os limites superior (LS) para detecção de outliers para cada coluna
ls = [q3 - 1.5 * aiq for q3, aiq in zip(q3, aiq)]

# Adicionar os valores calculados ao DataFrame 'medidas' como uma nova linha
medidas.loc['AIQ'] = aiq  # Adiciona os valores do AIQ como uma nova linha com o rótulo 'AIQ'
medidas.loc['LI'] = li    # Adiciona os valores do LI como uma nova linha com o rótulo 'LI'
medidas.loc['LS'] = ls    # Adiciona os valores do LS como uma nova linha com o rótulo 'LS'
display(medidas)
# Out:
#              idade    altura      massa
# count     7.000000  7.000000   7.000000
# mean     39.714286  1.674286  67.428571
# std      21.646511  0.207514  23.408383
# min       7.000000  1.230000  22.000000
# 25%      27.500000  1.670000  64.500000
# 50%      42.000000  1.730000  68.000000
# 75%      54.500000  1.785000  78.500000
# max      65.000000  1.850000  96.000000
# mediana  42.000000  1.730000  68.000000
# AIQ      27.000000  0.115000  14.000000
# LI      -13.000000  1.497500  43.500000
# LS       14.000000  1.612500  57.500000
